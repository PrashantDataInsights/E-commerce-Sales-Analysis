# %%
import pandas as pd
from prophet import Prophet
import matplotlib.pyplot as plt

df = pd.read_csv('Superstore_cleaned.csv', encoding='latin1')
df_forecast = df[['Order Date', 'Sales']].copy()
df_forecast.columns = ['ds', 'y']
df_forecast['ds'] = pd.to_datetime(df_forecast['ds'])
m = Prophet()
m.fit(df_forecast)
future = m.make_future_dataframe(periods=90)
forecast = m.predict(future)
m.plot(forecast)
plt.show()
forecast[['ds', 'yhat']].to_csv('sales_prediction.csv', index=False)
# Out:
# 01:22:37 - cmdstanpy - INFO - Chain [1] start processing
# 01:22:40 - cmdstanpy - INFO - Chain [1] done processing
